# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#df1 = pd.read_csv('inference_cnn.csv', sep=' ', header=None)
#old_us = df1[4].apply(lambda x:x.split('/')[0])
#old_us[old_us=='1ms'] = '1000us'
#old_us = old_us.apply(lambda x:x.split('u')[0]).astype(int)
#old_us.mean()

# %%
cnn_cpu = [683, 1140, 4223, 35252]
cnn_gpu = [577, 589, 596, 1237]
lstm_cpu = [4551, 5837, 12246, 73089]
lstm_gpu = [1288, 1351, 1548, 2635]
cnn_lstm_cpu = [5365, 6672, 13274, 86881]
cnn_lstm_gpu = [1692, 1740 , 1899, 2818]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches
sns.set_theme(style="white")

fig, ax = plt.subplots(figsize=(10,6))

#plt.ylim(bottom=500top=950)
plt.xlim(left=-0.3,right=3.2)
plt.ylim(bottom=480,top=3500)
plt.xticks(ticks=range(0,4),fontsize=22)
plt.yticks(fontsize=22)
plt.xlabel('$Number ~of~ sequences$', fontsize=22)
plt.ylabel('Inference Time ($\mu s$)', fontsize=22)


a_val=1
colors = {'(CPU) Hybrid-P':'b', '(CPU) Hybrid-P-EEG':'darkorange', 
          #'(GPU) Hybrid-P':'g', '(GPU) Hybrid-P-EEG':'r', 
         }
#circ1 = mpatches.Patch(facecolor='b',alpha=a_val,label='(CPU) EEGNet-SE')
#circ2 = mpatches.Patch(facecolor='g',alpha=a_val,label='(CPU) LSTM')
#circ3 = mpatches.Patch(facecolor='red',alpha=a_val,label='(CPU) Hybrid-P-EEG')
circ4 = mpatches.Patch(facecolor='darkblue',alpha=a_val,hatch=r'//',label='EEGNet-SE')
circ5 = mpatches.Patch(facecolor='darkgreen',alpha=a_val,hatch=r'//',label='LSTM')
circ6 = mpatches.Patch(facecolor='darkred',alpha=a_val,hatch='//',label='Hybrid-P-EEG')
labels = list(colors.keys())
handles = [plt.Rectangle((100,100),0.1,0.1, color=colors[label]) for label in labels]
handles = [#circ1,circ2,circ3,
           circ4, circ5, circ6]
#plt.legend(handles, labels, fontsize=16,loc = 'upper right')
plt.legend(handles=handles, fontsize=22,loc = 'best')

#plt.plot(cpu6,linewidth=5, marker='o',markersize=12)
#plt.plot(cpu5,linewidth=5, marker='^',markersize=12)
#plt.plot(gpu1,linewidth=5, marker='o',markersize=12)
#plt.plot(gpu2,linewidth=5, marker='^',markersize=12)


x = ['1', '10', '100', '1000']
x_int = np.array([0,1,2,3])#np.array([int(i) for i in x])
ax.set_xticklabels(x)
width = 0.1
#ax.bar(x_int-width*1.5, cnn_cpu, width,label='(CPU) EEGNet-SE')
#ax.bar(x_int-width/2, lstm_cpu, width,label='(CPU) LSTM')
ax.bar(x_int-width*1.5, cnn_gpu, width,label='EEGNet-SE', hatch='//', color='darkblue')
ax.bar(x_int-width/2, lstm_gpu, width,label='LSTM', hatch='//', color='darkgreen')
ax.bar(x_int+width/2, cnn_lstm_gpu, width,label='Hybrid-P-EEG', hatch='//', color='darkred')

fig.tight_layout()
plt.savefig('Inference_gpu_last.pdf')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches
sns.set_theme(style="white")

fig, ax = plt.subplots(figsize=(10,12))

#plt.ylim(bottom=500top=950)
plt.xlim(left=-0.3,right=3.4)
plt.ylim(bottom=480,top=88500)
plt.xticks(ticks=range(0,4),fontsize=22)
plt.yticks(fontsize=22)
plt.xlabel('$Number ~of~ sequences$', fontsize=22)
plt.ylabel('Inference Time ($\mu s$)', fontsize=22)


a_val=1
colors = {'(CPU) Hybrid-P':'b', '(CPU) Hybrid-P-EEG':'darkorange', 
          #'(GPU) Hybrid-P':'g', '(GPU) Hybrid-P-EEG':'r', 
         }
circ1 = mpatches.Patch(facecolor='b',alpha=a_val,label='EEGNet-SE')
circ2 = mpatches.Patch(facecolor='g',alpha=a_val,label='LSTM')
circ3 = mpatches.Patch(facecolor='red',alpha=a_val,label='Hybrid-P-EEG')
#circ4 = mpatches.Patch(facecolor='darkblue',alpha=a_val,hatch=r'//',label='(GPU) EEGNet-SE')
#circ5 = mpatches.Patch(facecolor='darkgreen',alpha=a_val,hatch=r'//',label='(GPU) LSTM')
#circ6 = mpatches.Patch(facecolor='darkred',alpha=a_val,hatch='//',label='(GPU) Hybrid-P-EEG')
labels = list(colors.keys())
handles = [plt.Rectangle((100,100),0.1,0.1, color=colors[label]) for label in labels]
handles = [circ1,circ2,circ3,
           #circ4, circ5, circ6
            ]
#plt.legend(handles, labels, fontsize=16,loc = 'upper right')
plt.legend(handles=handles, fontsize=22,loc = 'best')

#plt.plot(cpu6,linewidth=5, marker='o',markersize=12)
#plt.plot(cpu5,linewidth=5, marker='^',markersize=12)
#plt.plot(gpu1,linewidth=5, marker='o',markersize=12)
#plt.plot(gpu2,linewidth=5, marker='^',markersize=12)


x = ['1', '10', '100', '1000']
x_int = np.array([0,1,2,3])#np.array([int(i) for i in x])
ax.set_xticklabels(x)
width = 0.1
#ax.bar(x_int-width*1.5, cnn_cpu, width,label='(CPU) EEGNet-SE')
#ax.bar(x_int-width/2, lstm_cpu, width,label='(CPU) LSTM')
ax.bar(x_int-width*1.5, cnn_cpu, width,label='EEGNet-SE', hatch='', color='blue')
ax.bar(x_int-width/2, lstm_cpu, width,label='LSTM', hatch='', color='green')
ax.bar(x_int+width/2, cnn_lstm_cpu, width,label='Hybrid-P-EEG', hatch='', color='red')

fig.tight_layout()
plt.savefig('Inference_cpu_last.pdf')

# %%
handles

# %%
cpu6

# %%
# time unit 1e-6 sec, 
# 1, 10, 100, 1000, 1000
cnn_cpu = [683, 1140, 4223, 35252]
cnn_gpu = [577, 589, 596, 1237]
lstm_cpu = [4551, 5837, 12246, 73089]
lstm_gpu = [1288, 1351, 1548, 3035]
cnn_lstm_cpu = [5365, 6672, 13274, 86881]
cnn_lstm_gpu = [1692, 1740 , 1899, 2818]

# %%
import seaborn as sns

sns.set_theme(style="white")

fig, ax = plt.subplots(figsize=(10,7))

#plt.ylim(bottom=500top=950)
plt.xlim(left=-0.1,right=3.1)
plt.ylim(bottom=480,top=50000)
plt.xticks(ticks=range(0,4),fontsize=22)
#plt.yticks(ticks=range(400,50000,100), fontsize=22)
plt.xlabel('$Number ~of~ sequences$', fontsize=22)
plt.ylabel('Inference Time (us)', fontsize=22)
colors = {'(CPU) EEGNet-SE':'b', '(CPU) LSTM':'darkorange', '(CPU) Hybrid-P-EEG': 'orange',
          '(GPU) EEGNet-SE':'g', '(GPU) LSTM':'r', '(GPU) Hybrid-P-EEG': 'darkred'
         }         
labels = list(colors.keys())
handles = [plt.Rectangle((100,100),1,1, color=colors[label]) for label in labels]
plt.legend(handles, labels, fontsize=22,)


plt.plot(cnn_cpu,linewidth=5, marker='o',markersize=12)
plt.plot(lstm_cpu,linewidth=5, marker='^',markersize=12)
plt.plot(cnn_gpu,linewidth=5, marker='o',markersize=12)
plt.plot(lstm_gpu,linewidth=5, marker='^',markersize=12)
plt.plot(cnn_lstm_cpu,linewidth=5, marker='o',markersize=12)
plt.plot(cnn_lstm_gpu,linewidth=5, marker='^',markersize=12)

x = ['1', '10', '100', '1000']
ax.set_xticklabels(x)

fig.tight_layout()
#plt.savefig('Inference_cpu.pdf')

# %%
cpu5
# Out:
# [476.765, 589.544, 871.853, 823.822, nan]

# %%
([old_us4[i*50:i*50+50].mean() for i in range(0,5)])
# Out:
# [471.16, 577.38, 917.2, 830.7, 841.06]

# %%
cpu5[1] = 584.9787664307381

# %%
([old_us5[i*1000:i*1000+1000].mean() for i in range(0,5)])
# Out:
# [476.765, 589.544, 871.853, 823.822, nan]

# %%
([old_us6[i*1000:i*1000+1000].mean() for i in range(0,5)])
# Out:
# [493.988, 587.906, 879.732, 825.367, nan]

# %%
old_us5[1000:2000][old_us5[1000:2000]!=1000].mean()
# Out:
# 584.9787664307381

# %%
old_us6[1000:2000][old_us6[1000:2000]!=1000].mean()
# Out:
# 580.7792472024415

# %%
df7 = pd.read_csv('inference_eeg_1000_1.0.csv', sep=' ', header=None)
old_us7 = df7[4].apply(lambda x:x.split('/')[0])
old_us7[old_us7=='1ms'] = '1000us'
old_us7[old_us7=='2ms'] = '2000us'
old_us7 = old_us7.apply(lambda x:x.split('u')[0]).astype(int)
print(old_us7[3:].mean())
#plt.plot([old_us3[i*50:i*50+50].mean() for i in range(0,5)])
#plt.plot([old_us4[i*50:i*50+50].mean() for i in range(0,5)])
#plt.plot([old_us5[i*1000:i*1000+1000].mean() for i in range(0,5)])
#plt.plot([old_us7[i*1000:i*1000+1000].mean() for i in range(0,1)])
# Out:
# 603.5265797392177

# %%
old_us7.describe()
# Out:
# count    1000.000000
# mean      604.628000
# std       129.137354
# min       443.000000
# 25%       531.000000
# 50%       555.000000
# 75%       610.000000
# max      2000.000000
# Name: 4, dtype: float64
